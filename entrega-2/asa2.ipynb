# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import subprocess
from math import sqrt

DATA_DIR = "./data"
# %matplotlib inline

#X_VALS = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

X_VALS = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]



Y_VALS = [0.752, 2.292, 3.621, 6.208, 5.952, 11.614, 13.488, 18.858, 22.672, 24.165]
#FIX LAST Y_VALUE
#SCALE = np.array([0.15] * 10)

#Y_VALS = [1.722, 3.914, 5.941, 8.225, 9.913, 11.544, 13.488, 15.244, 17.324, 19.274]
#Y_VALS = [ ]

# %%
# Plot a matplotlib graph w/ X_VALS and Y_VALS
# Additionally, show points as red circles

#X axis every 5 points
#plt.xticks(np.arange(min(X_VALS), max(X_VALS)+1, 5.0))

#Draw a log(x) line starting at 0
# scale the graphic
fig = plt.figure(figsize=(10, 10))
plt.plot(X_VALS, X_VALS  *  np.log(X_VALS) * 3.4, '-r')
#plt.plot(X_VALS, X_VALS)
# Fit a line to X_VALS and Y_VALS 
m, b = np.polyfit(X_VALS, Y_VALS, 1)
# PLot fitted line
# Plot points, no line
plt.plot(X_VALS, Y_VALS, '-gD')
#plt.plot(X_VALS, m * np.array(X_VALS) + b, 'b')
#plt.plot(X_VALS, Y_VALS, '-gD')
#plt.plot(X_VALS, Y_VALS)
plt.xlabel("Nº de Arcos (10⁶)")
plt.ylabel("Tempo (s)")
#plt.title("Solução)")
plt.legend(['E log(E)', 'Tempo'], loc='upper left')
plt.show()

# Legendas
